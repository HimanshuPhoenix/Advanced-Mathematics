# %% [markdown]
# | tex | output |
# |------|-------|
# |\frac{\partial x}{\partial y}|$\frac{\partial x}{\partial y}$|
# |\sqrt{t}|$\sqrt{t}$|
# |\begin{pmatrix}1 & 9 & 0 \\ 5 & 8 & 10 \\ 7 & 4 & 6 \end{pmatrix}|$\begin{pmatrix}1 & 9 & 0 \\ 5 & 8 & 10 \\ 7 & 4 & 6 \end{pmatrix}$|
# |\begin{pmatrix}1\\2\\4 \end{pmatrix} | $\begin{pmatrix}1\\2\\4\end{pmatrix}$|
# |\vec{a}\cdot\vec{b}|$\vec{a}\cdot\vec{b}$|
# |\vec{d}\times\vec{e}|$\vec{d}\times\vec{e}$|
# |a\pm b|$a\pm b$|
# |\lim_{z\rightarrow\infty}|$\lim_{z\rightarrow\infty}$|
# |e^{n}|$e^{n}$|
# |e^{\infty}|$e^{\infty}$|
# |\sqrt[b]{x}|$\sqrt[b]{x}$|
# |\int sin(x)dx|$\int sin(x)dx$|
# |\int_{a}^{b} sin(x)dx|$\int_{a}^{b} sin(x)dx$|
# |\sum_{k=0}^{\infty} f^k (x)| $\sum_{k=0}^{\infty} f^k (x)$|
# |\sum_{k=0}^{\infty} \frac{f^{k} (x)}{k!}| $\sum_{k=0}^{\infty} \frac{f^{k} (x)}{k!}$|
# |sin(x)\|_{0}^{1}|$sin(x)\|_{0}^{1}$|

# %% [markdown]
# $\begin{pmatrix}a & b \\ c & d \end{pmatrix}$

# %% [markdown]
# $\begin{pmatrix}1 \\ 0 \\ 2 \end{pmatrix}$
#
# $\vec{v}$
